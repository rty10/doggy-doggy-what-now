# %%
import pandas as pd
import numpy as np

# %%
#Import Bloomington,IN data into dataframe called "bloom"
bloom = pd.read_csv("../main_data/locale_specific_data/BloomingtonData.csv")
bloom.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 4  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
#
#   identichipnumber animalname                breedname     basecolour  \
# 0       0A115D7358     Jadzia      Domestic Short Hair  Tortoiseshell
# 1       0A11675477      Gonzo  German Shepherd Dog/Mix            Tan
# 2       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 3       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 4       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
#
#   speciesname  ...            movementdate movementtype istrial  \
# ...

# %%
#Remove duplicate rows
print("#rows before removing duplicates:",bloom.shape[0])
bloom1=bloom.drop_duplicates()
print("#rows after removing duplicates:",bloom1.shape[0])
# Out:
# #rows before removing duplicates: 34130
# #rows after removing duplicates: 30839

# %%
#Restrict to dogs
bloomDogs = bloom1.loc[bloom1['speciesname'] == 'Dog']
bloomDogs.head(10)
# Out:
#        id              intakedate                       intakereason  \
# 1   15932  12/08/2009 12:00:00 AM                             Moving
# 2   28859  08/10/2012 12:00:00 AM                          Abandoned
# 3   28859  08/10/2012 12:00:00 AM                          Abandoned
# 4   28859  08/10/2012 12:00:00 AM                          Abandoned
# 5   28859  08/10/2012 12:00:00 AM                          Abandoned
# 9   31469  03/26/2013 12:00:00 AM  Incompatible with owner lifestyle
# 10  31469  03/26/2013 12:00:00 AM  Incompatible with owner lifestyle
# 13  46238  10/09/2016 12:00:00 AM                          Abandoned
# 14  46238  10/09/2016 12:00:00 AM                          Abandoned
# 15  46238  10/09/2016 12:00:00 AM                          Abandoned
#
#     istransfer sheltercode identichipnumber animalname  \
# 1        False   D09125594       0A11675477      Gonzo
# 2        False   D23111515       0A13253C7B     Maggie
# ...

# %%
import pandas as pd
import numpy as np

# %%
#Import Bloomington,IN data into dataframe called "bloom"
bloom = pd.read_csv("../main_data/locale_specific_data/BloomingtonData.csv")
bloom.head()
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 0  15801  11/28/2009 12:00:00 AM       Moving       False   C09115463
# 1  15932  12/08/2009 12:00:00 AM       Moving       False   D09125594
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 4  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
#
#   identichipnumber animalname                breedname     basecolour  \
# 0       0A115D7358     Jadzia      Domestic Short Hair  Tortoiseshell
# 1       0A11675477      Gonzo  German Shepherd Dog/Mix            Tan
# 2       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 3       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 4       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
#
#   speciesname  ...            movementdate movementtype istrial  \
# ...

# %%
#Restrict to dogs
bloomDogs = bloom.loc[bloom['speciesname'] == 'Dog']
bloomDogs.head(10)
# Out:
#        id              intakedate                       intakereason  \
# 1   15932  12/08/2009 12:00:00 AM                             Moving
# 2   28859  08/10/2012 12:00:00 AM                          Abandoned
# 3   28859  08/10/2012 12:00:00 AM                          Abandoned
# 4   28859  08/10/2012 12:00:00 AM                          Abandoned
# 5   28859  08/10/2012 12:00:00 AM                          Abandoned
# 6   28859  08/10/2012 12:00:00 AM                          Abandoned
# 9   31469  03/26/2013 12:00:00 AM  Incompatible with owner lifestyle
# 10  31469  03/26/2013 12:00:00 AM  Incompatible with owner lifestyle
# 13  46238  10/09/2016 12:00:00 AM                          Abandoned
# 14  46238  10/09/2016 12:00:00 AM                          Abandoned
#
#     istransfer sheltercode identichipnumber animalname  \
# 1        False   D09125594       0A11675477      Gonzo
# 2        False   D23111515       0A13253C7B     Maggie
# ...

# %%
#checking for duplicate IDs
duplicate_rows = bloomDogs.duplicated(subset=['id'])
sum(duplicate_rows)
# Out:
# 6550

# %%
bloomDogs["deceasedreason"].unique()
# Out:
# array(['Died in care', 'Healthy', 'Dead On Arrival',
#        'UU - untreatable, unmanageable health', 'Biting',
#        'Owner Requested', 'Temperament/Behavior', 'Court Order/ Legal',
#        'UU-untreatable, unmanageable Behavior', 'Medical',
#        'Vet advised euthanasia', 'TM - Treatable Manageable Behavior',
#        'Died in community', 'TR-Treatable rehabilitable Behavior',
#        'TM-Treatable Manageable Health'], dtype=object)

# %%
#Getting full list of original columns
cols = bloomDogs.columns
cols
# Out:
# Index(['id', 'intakedate', 'intakereason', 'istransfer', 'sheltercode',
#        'identichipnumber', 'animalname', 'breedname', 'basecolour',
#        'speciesname', 'animalage', 'sexname', 'location', 'movementdate',
#        'movementtype', 'istrial', 'returndate', 'returnedreason',
#        'deceaseddate', 'deceasedreason', 'diedoffshelter', 'puttosleep',
#        'isdoa'],
#       dtype='object')

# %%
#Looking at special case of repeated id
bloomcase = bloomDogs.loc[bloom['id'] == 28859]
bloomcase
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 4  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 5  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 6  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
#
#   identichipnumber animalname                breedname     basecolour  \
# 2       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 3       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 4       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 5       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 6       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
#
#   speciesname  ...            movementdate movementtype istrial  \
# ...

# %%
#Checking data types
bloomDogs.dtypes
# Out:
# id                   int64
# intakedate          object
# intakereason        object
# istransfer            bool
# sheltercode         object
# identichipnumber    object
# animalname          object
# breedname           object
# basecolour          object
# speciesname         object
# animalage           object
# sexname             object
# location            object
# movementdate        object
# movementtype        object
# istrial               bool
# returndate          object
# returnedreason      object
# deceaseddate        object
# deceasedreason      object
# diedoffshelter        bool
# puttosleep            bool
# isdoa                 bool
# dtype: object

# %%
#Confirming lack of  spay/neuter information 
bloomDogs["sexname"].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
bloomDogs.loc[6]
# Out:
# id                                    28859
# intakedate           08/10/2012 12:00:00 AM
# intakereason                      Abandoned
# istransfer                            False
# sheltercode                       D23111515
# identichipnumber                 0A13253C7B
# animalname                           Maggie
# breedname           Shep Mix/Siberian Husky
# basecolour                    Black and Tan
# speciesname                             Dog
# animalage                11 years 9 months.
# sexname                              Female
# location                             Office
# movementdate                            NaN
# movementtype                            NaN
# istrial                               False
# returndate                              NaN
# returnedreason                        Stray
# deceaseddate                            NaN
# deceasedreason                 Died in care
# diedoffshelter                        False
# ...

# %%
sum(duplicate_rows)
# Out:
# 6550

# %%
#Finding the ids with large number of repetitions
bloomDogs["id"].value_counts()
# Out:
# id
# 72299    42
# 74031    32
# 64999    27
# 72249    25
# 72513    23
#          ..
# 63414     1
# 63411     1
# 63410     1
# 63402     1
# 79986     1
# Name: count, Length: 6674, dtype: int64

# %%
#Finding the ids with large number of repetitions (all are with more than 15 occurences are shown)
bloomDogs[bloomDogs['id'].map(bloomDogs['id'].value_counts()) >15]["id"].value_counts()
# Out:
# id
# 72299    42
# 74031    32
# 64999    27
# 72249    25
# 72513    23
# 73703    21
# 77998    21
# 71109    21
# 72070    20
# 60639    20
# 73321    19
# 57223    19
# 73730    18
# 76032    18
# 72138    17
# 73335    17
# 63249    17
# 74447    17
# 74498    17
# 72415    16
# Name: count, dtype: int64

# %%
bloomDogs["istransfer"].value_counts()
# Out:
# istransfer
# False    13167
# True        57
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Angela: Check this -- why 57 "istransfer" true vs 241 "transfer from other shelter" below.
# </div>

# %%
bloomDogs["intakereason"].unique()
# Out:
# array(['Moving', 'Abandoned', 'Incompatible with owner lifestyle',
#        'Rabies Monitoring', 'Marriage/Relationship split', 'Stray',
#        'Police Assist', 'Biting', 'Unable to Afford',
#        'Unsuitable Accommodation', 'Owner Deceased',
#        'TNR - Trap/Neuter/Release', 'Transfer from Other Shelter',
#        'Sick/Injured', 'Allergies', 'Landlord issues',
#        'Litter relinquishment', 'Owner requested Euthanasia',
#        'Born in Shelter', 'Abuse/ neglect',
#        'Incompatible with other pets', 'Behavioral Issues',
#        'Return Adopt - Behavior', 'Return adopt - lifestyle issue',
#        'Return Adopt - Animal Health'], dtype=object)

# %%
bloomDogs["intakereason"].value_counts()
# Out:
# intakereason
# Stray                                6533
# Incompatible with owner lifestyle    1535
# Litter relinquishment                 733
# Unsuitable Accommodation              632
# Police Assist                         563
# Moving                                489
# Abandoned                             399
# Unable to Afford                      347
# Landlord issues                       287
# Abuse/ neglect                        254
# Transfer from Other Shelter           241
# Owner Deceased                        196
# Born in Shelter                       173
# Incompatible with other pets          142
# Rabies Monitoring                     134
# Sick/Injured                          133
# Biting                                117
# Marriage/Relationship split           114
# TNR - Trap/Neuter/Release              53
# Allergies                              53
# Behavioral Issues                      39
# Owner requested Euthanasia             31
# ...

# %%
bloomDogs["movementtype"].unique()
# Out:
# array(['Adoption', 'Reclaimed', nan, 'Foster', 'Transfer', 'Stolen',
#        'Escaped'], dtype=object)

# %%
bloomDogs["movementtype"].value_counts()
# Out:
# movementtype
# Adoption     5363
# Reclaimed    2814
# Foster       1765
# Transfer      140
# Escaped         5
# Stolen          2
# Name: count, dtype: int64

# %%
bloomDogs["returnedreason"].value_counts()
# Out:
# returnedreason
# Stray                                11909
# Incompatible with owner lifestyle      355
# Return adopt - lifestyle issue         202
# Return Adopt - Behavior                171
# Biting                                  65
# Incompatible with other pets            63
# Police Assist                           52
# Moving                                  50
# Unsuitable Accommodation                50
# Return Adopt - Other                    45
# Landlord issues                         41
# Owner requested Euthanasia              41
# Rabies Monitoring                       33
# Behavioral Issues                       25
# Unable to Afford                        25
# Transfer from Other Shelter             19
# Abandoned                               18
# DOA                                     17
# Owner Deceased                          12
# Allergies                                9
# Litter relinquishment                    7
# ...

# %%
bloomDogs["deceasedreason"].value_counts()
# Out:
# deceasedreason
# Court Order/ Legal                       12529
# Died in care                               283
# UU-untreatable, unmanageable Behavior      157
# UU - untreatable, unmanageable health       91
# Owner Requested                             52
# Dead On Arrival                             39
# TM - Treatable Manageable Behavior          28
# Biting                                      16
# Temperament/Behavior                        11
# TR-Treatable rehabilitable Behavior          7
# Vet advised euthanasia                       4
# Medical                                      2
# Died in community                            2
# TM-Treatable Manageable Health               2
# Healthy                                      1
# Name: count, dtype: int64

# %%
#checking for duplicate IDs - dog IDs with more than one entry
duplicate_dogs = bloomDogs.duplicated(subset=['id'])
sum(duplicate_dogs)
# Out:
# 6550

# %%
bloomDogs["deceasedreason"].unique()
# Out:
# array(['Died in care', 'Healthy', 'Dead On Arrival',
#        'UU - untreatable, unmanageable health', 'Biting',
#        'Owner Requested', 'Temperament/Behavior', 'Court Order/ Legal',
#        'UU-untreatable, unmanageable Behavior', 'Medical',
#        'Vet advised euthanasia', 'TM - Treatable Manageable Behavior',
#        'Died in community', 'TR-Treatable rehabilitable Behavior',
#        'TM-Treatable Manageable Health'], dtype=object)

# %%
#Getting full list of original columns
cols = bloomDogs.columns
cols
# Out:
# Index(['id', 'intakedate', 'intakereason', 'istransfer', 'sheltercode',
#        'identichipnumber', 'animalname', 'breedname', 'basecolour',
#        'speciesname', 'animalage', 'sexname', 'location', 'movementdate',
#        'movementtype', 'istrial', 'returndate', 'returnedreason',
#        'deceaseddate', 'deceasedreason', 'diedoffshelter', 'puttosleep',
#        'isdoa'],
#       dtype='object')

# %%
#Looking at special case of repeated id
bloomcase = bloomDogs.loc[bloom['id'] == 28859]
bloomcase
# Out:
#       id              intakedate intakereason  istransfer sheltercode  \
# 2  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 3  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 4  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 5  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
# 6  28859  08/10/2012 12:00:00 AM    Abandoned       False   D23111515
#
#   identichipnumber animalname                breedname     basecolour  \
# 2       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 3       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 4       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 5       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
# 6       0A13253C7B     Maggie  Shep Mix/Siberian Husky  Black and Tan
#
#   speciesname  ...            movementdate movementtype istrial  \
# ...

# %%
#Checking data types
bloomDogs.dtypes
# Out:
# id                   int64
# intakedate          object
# intakereason        object
# istransfer            bool
# sheltercode         object
# identichipnumber    object
# animalname          object
# breedname           object
# basecolour          object
# speciesname         object
# animalage           object
# sexname             object
# location            object
# movementdate        object
# movementtype        object
# istrial               bool
# returndate          object
# returnedreason      object
# deceaseddate        object
# deceasedreason      object
# diedoffshelter        bool
# puttosleep            bool
# isdoa                 bool
# dtype: object

# %%
#Confirming lack of  spay/neuter information 
bloomDogs["sexname"].unique()
bloomDogs.loc[6]
# Out:
# id                                    28859
# intakedate           08/10/2012 12:00:00 AM
# intakereason                      Abandoned
# istransfer                            False
# sheltercode                       D23111515
# identichipnumber                 0A13253C7B
# animalname                           Maggie
# breedname           Shep Mix/Siberian Husky
# basecolour                    Black and Tan
# speciesname                             Dog
# animalage                11 years 9 months.
# sexname                              Female
# location                             Office
# movementdate                            NaN
# movementtype                            NaN
# istrial                               False
# returndate                              NaN
# returnedreason                        Stray
# deceaseddate                            NaN
# deceasedreason                 Died in care
# diedoffshelter                        False
# ...

# %%
#Total number of duplicate rows
sum(duplicate_rows)
# Out:
# 6550

# %%
#Finding the ids with large number of repetitions
bloomDogs["id"].value_counts()
# Out:
# id
# 72299    42
# 74031    32
# 64999    27
# 72249    25
# 72513    23
#          ..
# 63414     1
# 63411     1
# 63410     1
# 63402     1
# 79986     1
# Name: count, Length: 6674, dtype: int64

# %%
#Finding the ids with large number of repetitions (all are with more than 15 occurences are shown)
bloomDogs[bloomDogs['id'].map(bloomDogs['id'].value_counts()) >15]["id"].value_counts()
bloomDogs["istransfer"].value_counts()
# Out:
# istransfer
# False    13167
# True        57
# Name: count, dtype: int64

# %% [markdown]
# Angela: Check this -- why 57 "istransfer" true vs 241 "transfer from other shelter" below.
#
# Answer:  probably due to duplicate portions of rows

# %%
bloomDogs["intakereason"].unique()
# Out:
# array(['Moving', 'Abandoned', 'Incompatible with owner lifestyle',
#        'Rabies Monitoring', 'Marriage/Relationship split', 'Stray',
#        'Police Assist', 'Biting', 'Unable to Afford',
#        'Unsuitable Accommodation', 'Owner Deceased',
#        'TNR - Trap/Neuter/Release', 'Transfer from Other Shelter',
#        'Sick/Injured', 'Allergies', 'Landlord issues',
#        'Litter relinquishment', 'Owner requested Euthanasia',
#        'Born in Shelter', 'Abuse/ neglect',
#        'Incompatible with other pets', 'Behavioral Issues',
#        'Return Adopt - Behavior', 'Return adopt - lifestyle issue',
#        'Return Adopt - Animal Health'], dtype=object)

# %%
bloomDogs["intakereason"].value_counts()
# Out:
# intakereason
# Stray                                6533
# Incompatible with owner lifestyle    1535
# Litter relinquishment                 733
# Unsuitable Accommodation              632
# Police Assist                         563
# Moving                                489
# Abandoned                             399
# Unable to Afford                      347
# Landlord issues                       287
# Abuse/ neglect                        254
# Transfer from Other Shelter           241
# Owner Deceased                        196
# Born in Shelter                       173
# Incompatible with other pets          142
# Rabies Monitoring                     134
# Sick/Injured                          133
# Biting                                117
# Marriage/Relationship split           114
# TNR - Trap/Neuter/Release              53
# Allergies                              53
# Behavioral Issues                      39
# Owner requested Euthanasia             31
# ...

# %%
bloomDogs["movementtype"].unique()
# Out:
# array(['Adoption', 'Reclaimed', nan, 'Foster', 'Transfer', 'Stolen',
#        'Escaped'], dtype=object)

# %%
bloomDogs["movementtype"].value_counts()
# Out:
# movementtype
# Adoption     5363
# Reclaimed    2814
# Foster       1765
# Transfer      140
# Escaped         5
# Stolen          2
# Name: count, dtype: int64

# %%
bloomDogs["returnedreason"].value_counts()
# Out:
# returnedreason
# Stray                                11909
# Incompatible with owner lifestyle      355
# Return adopt - lifestyle issue         202
# Return Adopt - Behavior                171
# Biting                                  65
# Incompatible with other pets            63
# Police Assist                           52
# Moving                                  50
# Unsuitable Accommodation                50
# Return Adopt - Other                    45
# Landlord issues                         41
# Owner requested Euthanasia              41
# Rabies Monitoring                       33
# Behavioral Issues                       25
# Unable to Afford                        25
# Transfer from Other Shelter             19
# Abandoned                               18
# DOA                                     17
# Owner Deceased                          12
# Allergies                                9
# Litter relinquishment                    7
# ...

# %%
bloomDogs["deceasedreason"].value_counts()
# Out:
# deceasedreason
# Court Order/ Legal                       12529
# Died in care                               283
# UU-untreatable, unmanageable Behavior      157
# UU - untreatable, unmanageable health       91
# Owner Requested                             52
# Dead On Arrival                             39
# TM - Treatable Manageable Behavior          28
# Biting                                      16
# Temperament/Behavior                        11
# TR-Treatable rehabilitable Behavior          7
# Vet advised euthanasia                       4
# Medical                                      2
# Died in community                            2
# TM-Treatable Manageable Health               2
# Healthy                                      1
# Name: count, dtype: int64

# %%
bloomDogs.count()
# Out:
# id                  13224
# intakedate          13224
# intakereason        13224
# istransfer          13224
# sheltercode         13224
# identichipnumber    11888
# animalname          13224
# breedname           13223
# basecolour          13224
# speciesname         13224
# animalage           13224
# sexname             13224
# location            13224
# movementdate        10089
# movementtype        10089
# istrial             13224
# returndate           3613
# returnedreason      13224
# deceaseddate          462
# deceasedreason      13224
# diedoffshelter      13224
# puttosleep          13224
# isdoa               13224
# dtype: int64
